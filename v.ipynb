# %%
from torchvista import trace_model
import torch
from Agent import Linear_QNet
# Out:
# [warning] torchaudio available, but import failed and hence torchvista cannot trace torchaudio operations.               If you need torchaudio tracing, run `import torchaudio` separately to debug what is wrong.

# %%
model = Linear_QNet(20,128,3)
trace_model(model, torch.randn(20, 128, 3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model = Linear_QNet(20,128,3)
#       2 trace_model(model, torch.randn(20, 128, 3))
#
# NameError: name 'Linear_QNet' is not defined
